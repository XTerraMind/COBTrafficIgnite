# %%
#%pip install numpy
#%pip install pandas
#%pip install scikit-learn
#%pip install matplotlib

# %%
import pandas as pd
import matplotlib
import numpy
import sklearn

# %%
"""
Corridor Focus: HWY 12 & I
Intersections:
"""
# Out:
# '\nCorridor Focus: HWY 12 & I\nIntersections:\n'

# %%
i12 = pd.read_csv('Hwy_12___I_St_Vehicles_60min.csv')
i12_listed = i12[['=T("DateTime")', '=T("Northbound")', '=T("Southbound")', '', "Westbound"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 2
#       1 i12 = pd.read_csv('Hwy_12___I_St_Vehicles_60min.csv')
# ----> 2 i12_listed = i12[['=T("DateTime")', "Northbound", "Southbound", "Eastbound", "Westbound"]]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...
